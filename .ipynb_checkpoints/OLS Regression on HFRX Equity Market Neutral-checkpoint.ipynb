# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns

sns.set()

from IPython.display import display
from tools import make_track, ols_regression
from hc_graph import hc_stock
# Out:
# Open console to check js libs were loaded in page

# %% [markdown]
# ### Financial data loads and cleaning

# %%
# BNP Data
#bnp = pd.read_csv(r'financial_data/bnp_data.csv', parse_dates =True, sep=";", header= [3], index_col=0)
#bnp_wanted_ticker = ["US_USDLIBOR3M","USD_EUR"]
#bnp

# %%
# yahoo_prices
yahoo = pd.read_csv(r"financial_data/yahoo_prices.csv", index_col=0, parse_dates=True)

# MSCI
msci = pd.read_csv(r'financial_data/msci_data.csv', index_col=0, parse_dates=True, sep=";")

# HFRX
hfrx_all = pd.read_csv(r"financial_data/hfrx_daily_index_data.csv", index_col=0, parse_dates=True)
hfrx = hfrx_all['HFRXEMN']

# BNP
bnp = pd.read_csv(r"financial_data/bnp_data.csv", index_col=0, parse_dates=True, dayfirst=True)

# %%
prices = bnp.copy()
#prices = prices.join(msci, how="outer")
prices = prices.join(hfrx,how="outer")

# %%
prices.head()
# Out:
#             BNPIFEU  BNPIFUS  BNPIFJP  BNPIFCN  BNPIFFR  BNPIFGE  BNPIFGB  \
# 2003-03-31      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2003-04-01      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2003-04-02      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2003-04-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2003-04-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#             BNPIFCH  BNPIFKR  BNPIFUSC   ...     SPGSIZP   SPGSIKP   SPGSILP   \
# 2003-03-31      NaN      NaN       NaN   ...          NaN       NaN       NaN
# 2003-04-01      NaN      NaN       NaN   ...          NaN       NaN       NaN
# 2003-04-02      NaN      NaN       NaN   ...          NaN       NaN       NaN
# 2003-04-03      NaN      NaN       NaN   ...          NaN       NaN       NaN
# 2003-04-04      NaN      NaN       NaN   ...          NaN       NaN       NaN
#
#             SPGSGCP   SPGSSIP   BNPXCEB5  BNPXCEX5  BNPXCIG5  BNPXCHY5  \
# 2003-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2003-04-01       NaN       NaN       NaN       NaN       NaN       NaN
# 2003-04-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2003-04-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2003-04-04       NaN       NaN       NaN       NaN       NaN       NaN
#
#             HFRXEMN
# 2003-03-31  1000.00
# 2003-04-01  1002.52
# 2003-04-02   998.36
# 2003-04-03   996.87
# 2003-04-04   996.14
#
# [5 rows x 77 columns]

# %%
starts = prices.apply(lambda x:x.first_valid_index())
starts.T
# Out:
# BNPIFEU    2007-01-03
# BNPIFUS    2007-01-03
# BNPIFJP    2007-01-03
# BNPIFCN    2007-01-03
# BNPIFFR    2007-01-03
# BNPIFGE    2007-01-03
# BNPIFGB    2007-01-03
# BNPIFCH    2007-01-03
# BNPIFKR    2007-01-03
# BNPIFUSC   2007-01-03
# BNPIFBR    2007-01-03
# BNPIFAU    2007-01-03
# BNPIFHK    2007-01-03
# BNPIFTW    2007-01-03
# BNPIFSG    2007-01-03
# BNPIFIT    2007-01-03
# BNPIFSP    2007-01-03
# BNPIFSW    2007-01-03
# BNPIFNE    2007-01-03
# BNPIFRU    2007-01-03
# BNPIFEM    2007-01-03
# BNPIFJT    2007-01-03
# BNPIFE10   2007-01-03
# BNPIFEU2   2007-01-03
# BNPIFEU5   2007-01-03
# BNPIFE30   2007-01-03
# BNPIFJ10   2007-01-03
# BNPIFU10   2007-01-03
# BNPIFUS2   2007-01-03
# BNPIFU30   2007-01-03
#               ...
# BPFXHUF1   2007-01-03
# BPFXTRY1   2007-01-03
# BPFXZAR1   2007-01-03
# BPFXSGD1   2007-01-03
# BPFXMXN1   2007-01-03
# BPFXINR1   2007-01-03
# BPFXKRW1   2007-01-03
# BPFXPHP1   2007-01-03
# BPFXTWD1   2007-01-03
# BPFXBRL1   2007-01-03
# BPFXCLP1   2007-01-03
# BPFXCOP1   2007-01-03
# SPGSCLP    2007-01-03
# SPGSHOP    2007-01-03
# SPGSGOP    2007-01-03
# SPGSBRP    2007-01-03
# SPGSHUP    2007-01-03
# SPGSNGP    2007-01-03
# SPGSIAP    2007-01-03
# SPGSICP    2007-01-03
# SPGSIZP    2007-01-03
# SPGSIKP    2007-01-03
# SPGSILP    2007-01-03
# SPGSGCP    2007-01-03
# SPGSSIP    2007-01-03
# BNPXCEB5   2007-01-03
# BNPXCEX5   2007-01-03
# BNPXCIG5   2007-01-03
# BNPXCHY5   2007-01-03
# HFRXEMN    2003-03-31
# dtype: datetime64[ns]

# %%
prices = prices.ffill().dropna()
returns = prices.resample('7D').first().pct_change().dropna()
returns.head()
# Out:
#              BNPIFEU   BNPIFUS   BNPIFJP   BNPIFCN   BNPIFFR   BNPIFGE  \
# 2007-01-10 -0.023483 -0.001466 -0.016763 -0.107756 -0.019571 -0.018204
# 2007-01-17  0.012666  0.010691  0.018700  0.030176  0.008724  0.017329
# 2007-01-24  0.008973  0.005061  0.014536  0.005827  0.014211  0.008010
# 2007-01-31 -0.001924 -0.001982 -0.007496 -0.044726 -0.006004  0.004237
# 2007-02-07  0.016186  0.007990 -0.005236  0.033903  0.015707  0.017753
#
#              BNPIFGB   BNPIFCH   BNPIFKR  BNPIFUSC    ...     SPGSIZP   \
# 2007-01-10 -0.026017 -0.007456 -0.042665 -0.011683    ...    -0.093718
# 2007-01-17  0.005805  0.026870  0.014758  0.011742    ...    -0.032714
# 2007-01-24  0.016816  0.004151  0.008261  0.005709    ...     0.020582
# 2007-01-31 -0.017975 -0.000295 -0.020868  0.007186    ...    -0.058617
# 2007-02-07  0.027216  0.014780  0.048193  0.018974    ...    -0.091402
#
#             SPGSIKP   SPGSILP   SPGSGCP   SPGSSIP   BNPXCEB5  BNPXCEX5  \
# 2007-01-10  0.002933 -0.069354 -0.026047 -0.017759 -0.000401 -0.001956
# 2007-01-17  0.106841 -0.024658  0.032268  0.035757  0.000374  0.006688
# 2007-01-24  0.061126  0.087054  0.023616  0.029713  0.000264  0.004889
# 2007-01-31 -0.014240 -0.002640  0.005195  0.022376 -0.000240 -0.002941
# 2007-02-07 -0.017728 -0.071765 -0.000912  0.010317  0.000401  0.007013
#
#             BNPXCIG5  BNPXCHY5   HFRXEMN
# 2007-01-10 -0.000227  0.003355 -0.002974
# 2007-01-17  0.000248  0.006548  0.005351
# 2007-01-24  0.000831  0.006915  0.007785
# 2007-01-31  0.000085 -0.004284  0.008648
# 2007-02-07  0.000586  0.005486  0.007802
#
# [5 rows x 77 columns]

# %%
hrfx_returns = returns[["HFRXEMN"]]
bch_returns = returns.drop("HFRXEMN", axis=1)

size = 52
freq = 13
bounds = (-np.inf,np.inf)
total_weight = 1

df_weight = ols_regression(hrfx_returns, bch_returns, size, freq, boundaries=bounds, weight_sum=total_weight)

prices_for_track = prices.loc[df_weight.index[0]:].drop("HFRXEMN", axis=1)
replication = make_track(prices_for_track, df_weight)

df_res = prices.loc[replication.index][["HFRXEMN"]]
df_res["OLS"] = replication

df_res = df_res / df_res.iloc[0]

df_res.head()
# Out:
#              HFRXEMN       OLS
# 2008-01-09  1.000000  1.000000
# 2008-01-10  1.000700  0.997830
# 2008-01-11  0.996538  0.998448
# 2008-01-14  0.996826  0.999284
# 2008-01-15  0.986488  0.998284

# %%
df_res.plot(figsize=(13,6), linewidth=1)

# %%
g = hc_stock(df_res)
g.plot()
# Out:
# <div id