# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

from tools import make_track, ols_regression, make_ER, lasso_regression, lasso_regression_ic, ridge_regression,\
    kalman_filter, kalman_with_selection, selective_kalman_filter, replication_stats
from clustering import cluster, cluster_net
from hc_graph import hc_stock, hc_piechart, hc_spiderweb
# Out:
# Open console to check js libs were loaded in page

# %%
fund_name = 'NEIXCTAT'
pd.read_csv(r"financial_data/hfrx_index_names.csv", index_col=0)
# Out:
#                                              Full Name
# Name
# HFRXAR                      HFRX Absolute Return Index
# HFRXDS         HFRX ED: Distressed Restructuring Index
# HFRXMA                 HFRX ED: Merger Arbitrage Index
# HFRXSS               HFRX ED: Special Situations Index
# HFRXEMN           HFRX EH: Equity Market Neutral Index
# HFRXEHG              HFRX EH: Fundamental Growth Index
# HFRXEHV               HFRX EH: Fundamental Value Index
# HFRXEMC          HFRX Emerging Markets Composite Index
# HFRXEW            HFRX Equal Weighted Strategies Index
# HFRXEH                         HFRX Equity Hedge Index
# HFRXED                         HFRX Event Driven Index
# HFRXFIC               HFRX Fixed Income - Credit Index
# HFRXGL                    HFRX Global Hedge Fund Index
# HFRXM                             HFRX Macro/CTA Index
# HFRXSDV   HFRX Macro: Systematic Diversified CTA Index
# HFRXMD                   HFRX Market Directional Index
# HFRXMLP                                 HFRX MLP Index
# HFRXMREG                       HFRX Multi-Region Index
# HFRXNA                        HFRX North America Index
# HFRXRVA            HFRX Relative Value Arbitrage Index
# HFRXCA         HFRX RV: FI-Convertible Arbitrage Index
# HFRXRVMS                 HFRX RV: Multi-Strategy Index
# NEIXCTAT                           Newedge Trend Index

# %% [markdown]
# ### Financial data loads and cleaning

# %%
# US rate
US_rate = pd.read_csv(r"financial_data/USD_rates.csv", index_col=0, parse_dates=True, dayfirst=True)['3M']

# HFRX
hfrx_all = pd.read_csv(r"financial_data/hfrx_daily_index_data.csv", index_col=0, parse_dates=True, dayfirst=True).ffill()
hfrx = make_ER(hfrx_all[[fund_name]].dropna(), US_rate)

# BNP

bnp = pd.read_csv(r"financial_data/bnp_data.csv", index_col=0, parse_dates=True, dayfirst=True) #[["BNPIFEU","BNPIFUS",
                 #"BNPIFJP","BNPIFCN","BNPIFFR","BNPIFGE","BNPIFGB","BNPIFCH","BNPIFKR","BNPIFUSC","BNPIFBR",
                 #"BNPIFAU","BNPIFHK","BNPIFTW","BNPIFSG","BNPIFIT","BNPIFSP","BNPIFSW","BNPIFNE","BNPIFRU","BNPIFEM"]]

risk_premia = pd.read_pickle("financial_data/risk_premia_ER_FX_USD.pkl") #[["BNPICCE3","BNPIVMRU","BNPIAIRT","BNPIAIRU",
                  #"BNPIEC03","BNPIPLEE","BNPIPMEE","BNPIPQEE","BNPIPVEE","BNPILUEE","BNPIPMUH","BNPIPQUH",
                  #"BNPIPVUH","BNPIAIRG","BNPIAIRJ","BNPIAIRE"]]

# %%
df_info = pd.read_csv(r"financial_data/bnp_info.csv", index_col=0)
df_info.head()
# Out:
#          Asset Class     Style
# Ticker
# BNPIDRXA   Commodity     Carry
# BNPIF3AX   Commodity     Carry
# BNPIF3XM   Commodity  Momentum
# BPFXSTGU          FX     Value
# BNPICCE3      Equity     Carry

# %%
prices_all = bnp.join(risk_premia,how="inner").ffill().join(hfrx,how="inner")
prices_all.head()
# Out:
#                BNPIFEU     BNPIFUS     BNPIFJP     BNPIFCN     BNPIFFR  \
# 2007-01-03  251.659037  221.446381  123.569027  122.453216  213.419777
# 2007-01-04  250.891929  221.752767  124.485468  116.840530  212.022884
# 2007-01-05  247.941926  220.296431  122.435019  116.354951  210.202422
# 2007-01-08  247.619806  220.849207  122.435019  114.489675  209.896589
# 2007-01-09  247.980535  220.738811  123.630465  112.996176  210.556213
#
#                BNPIFGE     BNPIFGB     BNPIFCH   BNPIFKR    BNPIFUSC  \
# 2007-01-03  187.351929  143.396494  295.276204  289.6684  214.633123
# 2007-01-04  186.812785  142.625314  294.978808  285.5191  215.297053
# 2007-01-05  184.800752  141.220705  294.559578  283.5307  211.436575
# 2007-01-08  184.914022  140.466947  292.889470  280.1748  211.660237
# 2007-01-09  185.164783  140.518570  293.917702  281.4930  211.994064
#
#               ...     BNPIPQEE  BNPIPVEE  BNPILUEE  BNPIPMUH  BNPIPQUH  \
# 2007-01-03    ...     1.000000  1.000000  1.000000  1.000000  1.000000
# 2007-01-04    ...     0.996090  0.995580  0.997660  1.001242  1.000243
# 2007-01-05    ...     1.000518  1.000001  0.996420  0.999333  0.999586
# 2007-01-08    ...     1.005248  1.002365  0.997761  1.000212  0.998146
# 2007-01-09    ...     1.005052  1.002498  0.999367  1.001821  0.995801
#
#             BNPIPVUH  BNPIMDEA  BNPIAIFH  BNPICVXA  NEIXCTAT
# 2007-01-03  1.000000  1.000000       NaN       NaN   1.07227
# 2007-01-04  0.996902  1.000146       NaN       NaN   1.06343
# 2007-01-05  0.998485  0.989704       NaN       NaN   1.04381
# 2007-01-08  0.996573  0.988449       NaN       NaN   1.04345
# 2007-01-09  0.994901  0.988940       NaN       NaN   1.04955
#
# [5 rows x 105 columns]

# %%
returns_all = prices_all.pct_change().iloc[1:]
hrfx_returns = returns_all[[fund_name]]
returns_all = returns_all.drop(fund_name, axis=1)
prices_all = prices_all.drop(fund_name, axis=1)
prices_all = prices_all.bfill()

# %%
returns_all
# Out:
#              BNPIFEU   BNPIFUS   BNPIFJP   BNPIFCN   BNPIFFR   BNPIFGE  \
# 2007-01-04 -0.003048  0.001384  0.007416 -0.045835 -0.006545 -0.002878
# 2007-01-05 -0.011758 -0.006567 -0.016471 -0.004156 -0.008586 -0.010770
# 2007-01-08 -0.001299  0.002509  0.000000 -0.016031 -0.001455  0.000613
# 2007-01-09  0.001457 -0.000500  0.009764 -0.013045  0.003143  0.001356
# 2007-01-10 -0.008997  0.001735 -0.017251 -0.033081 -0.006237 -0.006607
# 2007-01-11  0.017941  0.005952 -0.005106 -0.016744  0.017858  0.017131
# 2007-01-12  0.001990  0.004983  0.012248  0.021456  0.001652  0.000129
# 2007-01-16 -0.001315  0.000004  0.009062  0.035391 -0.004284  0.002580
# 2007-01-31 -0.000804           NaN       NaN
# 2007-02-01  0.008533           NaN       NaN
# 2007-02-02  0.003752           NaN       NaN
# 2007-02-05 -0.001171           NaN       NaN
# 2007-02-06  0.006429           NaN       NaN
# 2007-02-07  0.003623           NaN       NaN
# 2007-02-08 -0.006622           NaN       NaN
# 2007-02-09  0.001909           NaN       NaN
# 2007-02-12 -0.000405           NaN       NaN
# 2007-02-13  0.004086           NaN       NaN
# 2007-02-14  0.007720           NaN       NaN
# 2007-02-15  0.003239           NaN       NaN
# ...              ...           ...       ...
# 2017-09-01 -0.000273  3.023006e-03  0.000617
# 2017-09-05 -0.001740 -4.628468e-03 -0.000887
# 2017-09-06 -0.001204  1.410592e-03  0.000364
# 2017-09-07  0.004132 -5.504623e-04  0.000989
# 2017-09-08 -0.003579 -2.168907e-03 -0.000977
# 2017-09-11  0.004011  9.875798e-04  0.001421
# 2017-09-12 -0.002281 -3.621482e-04  0.000576
# 2017-09-13 -0.004477 -2.231449e-03 -0.000358
# 2017-09-14 -0.002252  2.230035e-04  0.000459
# 2017-09-15 -0.001198 -3.583232e-04  0.000887
# 2017-09-18  0.001411  1.849716e-05 -0.000681
# 2017-09-19 -0.002015  3.096936e-04  0.000556
# 2017-09-20  0.000735 -9.140829e-04 -0.000212
# 2017-09-21 -0.006487  3.173946e-04 -0.001946
# 2017-09-22 -0.000976  3.118438e-04  0.000859
# 2017-09-25  0.002938 -9.176630e-04 -0.001573
# 2017-09-26 -0.002453  1.005991e-03  0.001156
# 2017-09-27 -0.001042  3.952633e-04  0.000235
# 2017-09-28 -0.002293  1.035306e-03  0.000427
# 2017-09-29 -0.001348  2.252397e-03  0.000627
# 2017-10-02 -0.001812 -9.341638e-04  0.000471
# 2017-10-03  0.008974  9.587314e-04  0.000757
# 2017-10-04  0.002890  9.696022e-04  0.000642
# 2017-10-05  0.003772 -9.451554e-04 -0.000495
# 2017-10-06 -0.003083  1.040279e-03 -0.000952
# 2017-10-09  0.000719  2.220446e-16  0.001085
# 2017-10-10  0.004607  1.077017e-04 -0.001228
# 2017-10-11  0.000975  1.228009e-04  0.000574
# 2017-10-12  0.003697  5.645987e-04 -0.000375
# 2017-10-13  0.006849  1.324253e-03 -0.000102
#
# [2669 rows x 104 columns]

# %%
alpha = hrfx_returns[fund_name].autocorr(lag=1)
hrfx_returns_adj = ((hrfx_returns - alpha * hrfx_returns.shift(1)) / (1. - alpha)).fillna(0) # 'liquidity adjustment' for
                                                                                             # removing returns autocorrelation
beta = hrfx_returns_adj[fund_name].autocorr(lag=1)

# %%
print("Auto-correlation of",fund_name,"returns :", alpha)
print("Auto-correlation of",fund_name,"adjusted returns :", beta)
ax = (1 + hrfx_returns).cumprod().plot()
_ = (1 + hrfx_returns_adj).cumprod()[fund_name].plot(label=fund_name + ' adjusted', legend=True, ax=ax)
# Out:
# Auto-correlation of NEIXCTAT returns : 0.0864993508251
# Auto-correlation of NEIXCTAT adjusted returns : 0.000497140384406

# %% [markdown]
# ## Estimation of the exposures

# %%
size = 126
freq = 5

# %%
# %%time
df_weight_aic, _ = lasso_regression_ic(hrfx_returns, returns_all,sample_length=size, frequency=freq, criterion='aic')
prices_for_track_aic = prices_all.loc[df_weight_aic.index[0]:]
# Out:
# Wall time: 44.6 s

# %%
# %%time
df_weight_bic, _ = lasso_regression_ic(hrfx_returns, returns_all,sample_length=size, frequency=freq, criterion='bic')
prices_for_track_bic = prices_all.loc[df_weight_bic.index[0]:]
# Out:
# Wall time: 44.1 s

# %%
# %%time
nu = 1.
df_weight_kalman = kalman_filter(hrfx_returns, returns_all,freq, sigma_weight=1. , sigma_return=nu)

prices_for_track_kalman = prices_all.loc[df_weight_kalman.index[0]:]
# Out:
# Wall time: 2.02 s

# %%
# %%time
df_weight_kalman_bic = selective_kalman_filter(hrfx_returns, returns_all,sample_length=size, frequency=freq,\
                                          nu=nu, criterion='bic')

prices_for_track_kalman_bic = prices_all.loc[df_weight_kalman_bic.index[0]:]
# Out:
# Wall time: 44.8 s

# %%
# %%time
df_weight_kalman_aic = selective_kalman_filter(hrfx_returns, returns_all,sample_length=size, frequency=freq,\
                                          nu=nu, criterion='aic')

prices_for_track_kalman_aic = prices_all.loc[df_weight_kalman_aic.index[0]:]
# Out:
# Wall time: 43.7 s

# %% [markdown]
# ## Replication

# %%
# %%time
tc = 0.0005
lag = 1

replication_aic = make_track(prices_for_track_aic, df_weight_aic, tc=tc, lag=lag)
df_res = hfrx.loc[replication_aic.index]
df_res["Lasso AIC"] = replication_aic

replication_bic = make_track(prices_for_track_bic, df_weight_bic, tc=tc, lag=lag)
df_res["Lasso BIC"] = replication_bic

replication_kalman = make_track(prices_for_track_kalman, df_weight_kalman, tc=tc, lag=lag).loc[df_res.index[0]:]
df_res["Kalman"] = replication_kalman

replication_kalman_aic = make_track(prices_for_track_kalman_aic, df_weight_kalman_aic, tc=tc, lag=lag).loc[df_res.index[0]:]
df_res["Kalman AIC"] = replication_kalman_aic

replication_kalman_bic = make_track(prices_for_track_kalman_bic, df_weight_kalman_bic, tc=tc, lag=lag).loc[df_res.index[0]:]
df_res["Kalman BIC"] = replication_kalman_bic
# Out:
# Wall time: 13 s

# %%
df_res = (df_res / df_res.iloc[0])
df_res[[fund_name, 'Kalman', 'Kalman BIC', 'Kalman AIC']].plot(figsize=(20,10))

# %%
df_stat = replication_stats(df_res, fund_name=fund_name)
df_stat
# Out:
#             Tracking error  R-squared  Sharpe ratio Annual Return  \
# NEIXCTAT          0.000000   1.000000      0.167125     0.0126393
# Lasso AIC         0.004968   0.524989      0.497891     0.0373837
# Lasso BIC         0.005279   0.463617      0.452103     0.0269934
# Kalman            0.004706   0.573713      0.675993      0.062587
# Kalman AIC        0.005184   0.482807      0.695211     0.0532541
# Kalman BIC        0.005484   0.421070      0.622536     0.0433972
#
#             Correlation  Kendall tau
# NEIXCTAT       1.000000     1.000000
# Lasso AIC      0.725092     0.528141
# Lasso BIC      0.695650     0.504329
# Kalman         0.762144     0.569075
# Kalman AIC     0.694997     0.509477
# Kalman BIC     0.649267     0.477368

# %%
vol = df_res.pct_change().rolling(window=60).std().dropna()
vol[[fund_name, 'Kalman', 'Kalman BIC', 'Kalman AIC']].plot(figsize=(20,10), title='60-day volatility')

# %% [markdown]
# ### Volatility adjustment

# %%
# %%time
df_weight_kalman_aic_voladj = selective_kalman_filter(hrfx_returns, returns_all,sample_length=size, frequency=freq,\
                                          nu=nu, criterion='aic', vol_target=True)
df_weight_kalman_bic_voladj = selective_kalman_filter(hrfx_returns, returns_all,sample_length=size, frequency=freq,\
                                          nu=nu, criterion='bic', vol_target=True)
df_weight_kalman_voladj = kalman_filter(hrfx_returns, returns_all,freq, sigma_weight=1. , sigma_return=nu, vol_target=True)


prices_for_track = prices_all.loc[df_weight_kalman_aic_voladj.index[0]:]

replication_kalman_aic_voladj = make_track(prices_for_track, df_weight_kalman_aic_voladj, tc=tc, lag=lag)
df_res_voladj = hfrx.loc[replication_kalman_aic_voladj.index]
df_res_voladj["Kalman AIC"] = replication_kalman_aic_voladj

replication_kalman_bic_voladj = make_track(prices_for_track, df_weight_kalman_bic_voladj, tc=tc, lag=lag)
df_res_voladj["Kalman BIC"] = replication_kalman_bic_voladj

prices_for_track = prices_all.loc[df_weight_kalman_voladj.index[0]:]

replication_kalman_voladj = make_track(prices_for_track, df_weight_kalman_voladj, tc=tc, lag=lag)
df_res_voladj["Kalman"] = replication_kalman_voladj
# Out:
# Wall time: 1min 34s

# %%
df_res_voladj = df_res_voladj.bfill()
df_res_voladj = (df_res_voladj / df_res_voladj.iloc[0])
df_res_voladj.plot(figsize=(20,10))

# %%
df_res_volperfadj = df_res_voladj[[fund_name]].copy()
temp = df_res_voladj.drop(fund_name, axis=1)
df_res_volperfadj[temp.columns]= make_ER(temp, 2 + 0 * US_rate)
df_res_volperfadj[[fund_name, 'Kalman', 'Kalman BIC', 'Kalman AIC']].plot(figsize=(20,10))

# %% [markdown]
# ## Statistics on replication

# %%
df_stat_vol = replication_stats(df_res_voladj, fund_name=fund_name)
df_stat_vol
# Out:
#             Tracking error  R-squared  Sharpe ratio  Annual Return  \
# NEIXCTAT          0.000000   1.000000      0.167125       0.012639
# Kalman AIC        0.005374   0.444111      0.614820       0.068454
# Kalman BIC        0.005720   0.370298      0.610077       0.068521
# Kalman            0.004932   0.531790      0.630942       0.070403
#
#             Correlation  Kendall tau
# NEIXCTAT       1.000000     1.000000
# Kalman AIC     0.734454     0.528762
# Kalman BIC     0.702807     0.499052
# Kalman         0.776064     0.572871

# %% [markdown]
# ## Volatility contributions

# %%
df_vol_contrib_kalman_voladj = (prices_all.reindex(df_weight_kalman_voladj.index).pct_change()*df_weight_kalman_voladj).std()
df_vol_contrib_kalman_voladj = df_vol_contrib_kalman_voladj/df_vol_contrib_kalman_voladj.sum()

df_vol_contrib_kalman_bic_voladj = (prices_all.reindex(df_weight_kalman_bic_voladj.index).pct_change()*df_weight_kalman_bic_voladj).std()
df_vol_contrib_kalman_bic_voladj = df_vol_contrib_kalman_bic_voladj/df_vol_contrib_kalman_bic_voladj.sum()

df_vol_contrib_kalman_aic_voladj = (prices_all.reindex(df_weight_kalman_aic_voladj.index).pct_change()*df_weight_kalman_aic_voladj).std()
df_vol_contrib_kalman_aic_voladj = df_vol_contrib_kalman_aic_voladj/df_vol_contrib_kalman_aic_voladj.sum()

# %%
df_vol_contrib = pd.DataFrame()
df_vol_contrib["Kalman"] = df_vol_contrib_kalman_voladj
df_vol_contrib["Kalman BIC"] = df_vol_contrib_kalman_bic_voladj
df_vol_contrib["Kalman AIC"] = df_vol_contrib_kalman_aic_voladj
df_vol_contrib = df_vol_contrib.join(df_info).reset_index()

# %%
df_vol_contrib_asset_class = df_vol_contrib.drop(["Style"],axis=1).groupby(["Asset Class","index"]).sum()
df_vol_contrib_style = df_vol_contrib.drop(["Asset Class"],axis=1).groupby(["Style","index"]).sum()

# %%
g = hc_spiderweb(df_vol_contrib_asset_class, title="Vol contribution by Asset Class")
g.plot()
# Out:
# <div id="526f8de3_df3b_4181_acd7_03ac2bfb6306"><div id="526f8de3_df3b_4181_acd7_03ac2bfb6306container_chart"></div></div><script>
#     // the Jupyter notebook loads jquery.min.js  and require.js and at the top of the page
#     // then to make jquery available inside a require module
#     // the trick is http://www.manuel-strehl.de/dev/load_jquery_before_requirejs.en.html
#     define('jquery', [], function() {
#         return jQuery;
#     });
#
#     require(["jquery", "https://code.highcharts.com/stock/highstock.js", "https://d3js.org/d3.v3.min.js"], function() {
#         require(["https://cdn.datatables.net/1.10.10/js/jquery.dataTables.min.js", "https://code.highcharts.com/stock/highcharts-more.js", "https://code.highcharts.com/modules/drilldown.js", "https://code.highcharts.com/modules/exporting.js", "https://code.highcharts.com/modules/heatmap.js", "https://code.highcharts.com/modules/treemap.js", "https://highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":{"enabled":true},"chart":{"animation":false,"polar":true,"width":800,"height":500,"renderTo":"526f8de3_df3b_4181_acd7_03ac2bfb6306container_chart"},"series":[{"name":"Kalman","data":[{"name":"Bonds","y":8.6757737332,"drilldown":"Bonds - Kalman","pointPlacement":"on"},{"name":"Commodity","y":26.0240471387,"drilldown":"Commodity - Kalman","pointPlacement":"on"},{"name":"Credit","y":1.1204754473,"drilldown":"Credit - Kalman","pointPlacement":"on"},{"name":"Cross-Asset","y":6.6372958415,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":35.7223803081,"drilldown":"Equity - Kalman","pointPlacement":"on"},{"name":"FX","y":21.8035255702,"drilldown":"FX - Kalman","pointPlacement":"on"},{"name":"MM","y":0.0165019611,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman BIC","data":[{"name":"Bonds","y":9.5739248895,"drilldown":"Bonds - Kalman BIC","pointPlacement":"on"},{"name":"Commodity","y":30.9784983068,"drilldown":"Commodity - Kalman BIC","pointPlacement":"on"},{"name":"Credit","y":0.3653401541,"drilldown":"Credit - Kalman BIC","pointPlacement":"on"},{"name":"Cross-Asset","y":13.7636385383,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":29.7868757448,"drilldown":"Equity - Kalman BIC","pointPlacement":"on"},{"name":"FX","y":15.5210949957,"drilldown":"FX - Kalman BIC","pointPlacement":"on"},{"name":"MM","y":0.0106273708,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman AIC","data":[{"name":"Bonds","y":9.3355861274,"drilldown":"Bonds - Kalman AIC","pointPlacement":"on"},{"name":"Commodity","y":31.5894675639,"drilldown":"Commodity - Kalman AIC","pointPlacement":"on"},{"name":"Credit","y":0.5071850735,"drilldown":"Credit - Kalman AIC","pointPlacement":"on"},{"name":"Cross-Asset","y":10.763606901,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y
highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":{"enabled":true},"chart":{"animation":false,"polar":true,"width":800,"height":500,"renderTo":"4b7258b6_9935_47c8_ac42_e51c645456aacontainer_chart"},"series":[{"name":"Kalman","data":[{"name":"Carry","y":5.1468871957,"drilldown":"Carry - Kalman","pointPlacement":"on"},{"name":"Classic","y":73.7244469671,"drilldown":"Classic - Kalman","pointPlacement":"on"},{"name":"Low Volatility","y":0.4514011668,"drilldown":"Low Volatility - Kalman","pointPlacement":"on"},{"name":"Momentum","y":14.467011282,"drilldown":"Momentum - Kalman","pointPlacement":"on"},{"name":"Quality","y":0.663366911,"drilldown":"Quality - Kalman","pointPlacement":"on"},{"name":"Reversal","y":1.1686512297,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":1.3179335437,"drilldown":"Value - Kalman","pointPlacement":"on"},{"name":"Volatility","y":3.0603017039,"drilldown":"Volatility - Kalman","pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman BIC","data":[{"name":"Carry","y":4.2143242367,"drilldown":"Carry - Kalman BIC","pointPlacement":"on"},{"name":"Classic","y":72.5616319344,"drilldown":"Classic - Kalman BIC","pointPlacement":"on"},{"name":"Low Volatility","y":0.0033882459,"drilldown":"Low Volatility - Kalman BIC","pointPlacement":"on"},{"name":"Momentum","y":22.745390679,"drilldown":"Momentum - Kalman BIC","pointPlacement":"on"},{"name":"Quality","y":0.0055184223,"drilldown":"Quality - Kalman BIC","pointPlacement":"on"},{"name":"Reversal","y":0.2801810961,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":0.0538291416,"drilldown":"Value - Kalman BIC","pointPlacement":"on"},{"name":"Volatility","y":0.135736244,"drilldown":"Volatility - Kalman BIC","pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman AIC","data":[{"name":"Carry","y":5.0635847239,"drilldown":"Carry - Kalman AIC","pointPlacement":"on"},{"name":"Classic","y":71.4763511342,"drilldown":"Classic - Kalman AIC","pointPlacement":"on"},{"name":"Low Volatility","y":0.0278066533,"drilldown":"Low Volatility - Kalman AIC","pointPlacement":"on"},{"name":"Momentum","y":20.5306799823,"drilldown":"Momentum - Kalman AIC","pointPlacement":"on"},{"name":"Quality","y":0.0256668433,"drilldown":"Quality - Kalman AIC","pointPlacement":"on"},{"name":"Reversal","y":0.7603182551,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":0.5847910019,"drilldown":"Value - Kalman AIC","pointPlacement":"on"},{"name":"Volatility","y":1.530801406,"drilldown":"Volatility - Kalman AIC","pointPlacement":"on"}],"colorByPoint":false}],"plotOptions":{"series":{"animation":true},"line":{"animation":false},"column":{"animation":false},"bar":{"animation":false},"pie":{"animation":false},"scatter":{"animation":false},"bubble":{"animation":false},"treemap":{"animation":false}},"pane":{"size":"90%"},"title":{"text":""},"xAxis":{"type":"category","tickmarkPlacement":"on","lineWidth":0},"yAxis":{"gridLineInterpolation":"polygon","lineWidth":0,"plotLines":[{"color":"gray","value":0,"width":1.5}]},"tooltip":{"pointFormat":"<span style=\"color:{series.color}\">{series.name}: <b>{point.y:,.3f}%<\/b><br\/>","shared":true},"legend":{"enabled":true,"align":"right","verticalAlign":"top","y":70,"layout":"vertical"},"drilldown":{"series":[{"name":"Carry - Kalman","data":[["BNPICCE3",0.8048331472],["BNPIDRXA",0.3722941803],["BNPIEC03",1.5845404381],["BNPIF3AX",1.2639903394],["BPCURVW4",0.0165019611],["BPFXGGUR",1.1047271297]],"id":"Carry - Kalman","pointPlacement":"on"},{"name":"Classic - Kalman","data":[["BNPIFA10",0.6618502762],["BNPIFAU",0.6535879857],["BNPIFAU3",0.0565907507],["BNPIFBR",1.3040907543],["BNPIFCH",0.6316845604],["BNPIFCN",1.4398950793],["BNPIFE10",0.3583417062],["BNPIFE30",2.4829187309],["BNPIFEM",3.6339899641],["BNPIFEU",2.255153226],["BNPIFEU2",0.0241125836],["BNPIFEU5",0.139043487],["BNPIFF10",0.4652357111],["BNPIFFR",0.9920730047],["BNPIFG10",1.1086195835],["BNPIFGB",0.8822639782],["BNPIFGE",1.2207290535],["BNPIFHK",0.829083864],["BNPIFI10 ...

# %%
g = hc_piechart(df_vol_contrib_asset_class[["Kalman BIC"]], title="Vol contribution by Asset Class in Kalman BIC")
g.plot()
# Out:
# <div id="1f05a054_9c17_4469_a3f0_a8ce6513ca3c"><div id="1f05a054_9c17_4469_a3f0_a8ce6513ca3ccontainer_chart"></div></div><script>
#     // the Jupyter notebook loads jquery.min.js  and require.js and at the top of the page
#     // then to make jquery available inside a require module
#     // the trick is http://www.manuel-strehl.de/dev/load_jquery_before_requirejs.en.html
#     define('jquery', [], function() {
#         return jQuery;
#     });
#
#     require(["jquery", "https://code.highcharts.com/stock/highstock.js", "https://d3js.org/d3.v3.min.js"], function() {
#         require(["https://cdn.datatables.net/1.10.10/js/jquery.dataTables.min.js", "https://code.highcharts.com/stock/highcharts-more.js", "https://code.highcharts.com/modules/drilldown.js", "https://code.highcharts.com/modules/exporting.js", "https://code.highcharts.com/modules/heatmap.js", "https://code.highcharts.com/modules/treemap.js", "https://highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":false,"chart":{"animation":false,"type":"pie","width":800,"height":500,"renderTo":"1f05a054_9c17_4469_a3f0_a8ce6513ca3ccontainer_chart"},"series":[{"name":"Kalman BIC","data":[{"name":"Bonds","y":9.5739248895,"drilldown":"Bonds - Kalman BIC","pointPlacement":"on"},{"name":"Commodity","y":30.9784983068,"drilldown":"Commodity - Kalman BIC","pointPlacement":"on"},{"name":"Credit","y":0.3653401541,"drilldown":"Credit - Kalman BIC","pointPlacement":"on"},{"name":"Cross-Asset","y":13.7636385383,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":29.7868757448,"drilldown":"Equity - Kalman BIC","pointPlacement":"on"},{"name":"FX","y":15.5210949957,"drilldown":"FX - Kalman BIC","pointPlacement":"on"},{"name":"MM","y":0.0106273708,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":true}],"plotOptions":{"series":{"animation":false},"line":{"animation":false},"column":{"animation":false},"bar":{"animation":false},"pie":{"animation":false,"showInLegend":false,"dataLabels":{"enabled":true,"format":"{point.name}: {point.y:.1f}%"},"center":["50%","50%"],"size":"65%"},"scatter":{"animation":false},"bubble":{"animation":false},"treemap":{"animation":false}},"drilldown":{"drillUpButton":{"position":{"x":0,"y":0}},"series":[{"name":"Bonds - Kalman BIC","data":[["BNPIAIRB",0.0000158907],["BNPIFA10",0.2870607186],["BNPIFAU3",0.0],["BNPIFE10",0.4385309192],["BNPIFE30",2.8947061869],["BNPIFEU2",0.0038032608],["BNPIFEU5",0.0255633257],["BNPIFF10",0.8936033914],["BNPIFG10",2.4690636091],["BNPIFI10",1.035227931],["BNPIFJ10",0.0097988137],["BNPIFU10",0.0709862915],["BNPIFU30",1.4138551728],["BNPIFUS2",0.0036249965],["BNPIFUS5",0.0280843818]],"id":"Bonds - Kalman BIC","pointPlacement":"on"},{"name":"Commodity - Kalman BIC","data":[["BNPICVXA",0.0],["B

#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#         if (check2) {
#             return eval(value);
#         }
#
#
#     }
#
#     return value;
# });
#
#
#
#     var opt = $.extend(true, {}, options);
#     if (window.opts==undefined) {
#         window.opts = {};
#     }
#     window.opts['1f05a054_9c17_4469_a3f0_a8ce6513ca3c'] = opt;
#
#     console.log('Highcharts/Highstock options accessible as opts["1f05a054_9c17_4469_a3f0_a8ce6513ca3c"]');
#
#
#             window.chart = new Highcharts.Chart(options);
#
#     console.log('Highcharts/Highstock chart accessible as charts["1f05a054_9c17_4469_a3f0_a8ce6513ca3c"]');
#
#         });
#     });
#     </script>

# %%
g = hc_piechart(df_vol_contrib_style[["Kalman BIC"]], title="Vol contribution by Style in Kalman BIC")
g.plot()
# Out:
# <div id="2e381496_c323_4b67_ad13_a09d907976f5"><div id="2e381496_c323_4b67_ad13_a09d907976f5container_chart"></div></div><script>
#     // the Jupyter notebook loads jquery.min.js  and require.js and at the top of the page
#     // then to make jquery available inside a require module
#     // the trick is http://www.manuel-strehl.de/dev/load_jquery_before_requirejs.en.html
#     define('jquery', [], function() {
#         return jQuery;
#     });
#
#     require(["jquery", "https://code.highcharts.com/stock/highstock.js", "https://d3js.org/d3.v3.min.js"], function() {
#         require(["https://cdn.datatables.net/1.10.10/js/jquery.dataTables.min.js", "https://code.highcharts.com/stock/highcharts-more.js", "https://code.highcharts.com/modules/drilldown.js", "https://code.highcharts.com/modules/exporting.js", "https://code.highcharts.com/modules/heatmap.js", "https://code.highcharts.com/modules/treemap.js", "https://highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":false,"chart":{"animation":false,"type":"pie","width":800,"height":500,"renderTo":"2e381496_c323_4b67_ad13_a09d907976f5container_chart"},"series":[{"name":"Kalman BIC","data":[{"name":"Carry","y":4.2143242367,"drilldown":"Carry - Kalman BIC","pointPlacement":"on"},{"name":"Classic","y":72.5616319344,"drilldown":"Classic - Kalman BIC","pointPlacement":"on"},{"name":"Low Volatility","y":0.0033882459,"drilldown":"Low Volatility - Kalman BIC","pointPlacement":"on"},{"name":"Momentum","y":22.745390679,"drilldown":"Momentum - Kalman BIC","pointPlacement":"on"},{"name":"Quality","y":0.0055184223,"drilldown":"Quality - Kalman BIC","pointPlacement":"on"},{"name":"Reversal","y":0.2801810961,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":0.0538291416,"drilldown":"Value - Kalman BIC","pointPlacement":"on"},{"name":"Volatility","y":0.135736244,"drilldown":"Volatility - Kalman BIC","pointPlacement":"on"}],"colorByPoint":true}],"plotOptions":{"series":{"animation":false},"line":{"animation":false},"column":{"animation":false},"bar":{"animation":false},"pie":{"animation":false,"showInLegend":false,"dataLabels":{"enabled":true,"format":"{point.name}: {point.y:.1f}%"},"center":["50%","50%"],"size":"65%"},"scatter":{"animation":false},"bubble":{"animation":false},"treemap":{"animation":false}},"drilldown":{"drillUpButton":{"position":{"x":0,"y":0}},"series":[{"name":"Carry - Kalman BIC","data":[["BNPICCE3",0.1152667758],["BNPIDRXA",0.0306275013],["BNPIEC03",2.3148370655],["BNPIF3AX",1.3509259324],["BPCURVW4",0.0106273708],["BPFXGGUR",0.392039591]],"id":"Carry - Kalman BIC","pointPlacement":"on"},{"name":"Classic - Kalman BIC","data":[["BNPIFA10",0.2870607186],["BNPIFAU",0.2166890127],["BNPIFAU3",0.0],["BNPIFBR",0.6520743905],["BNPIFCH",0.4828287435],["BNPIFCN",0.3861121632],["BNPIFE10",0.

#             var startBody = value.indexOf('{') + 1;
#             var endBody = value.lastIndexOf('}');
#             var startArgs = value.indexOf('(') + 1;
#             var endArgs = value.indexOf(')');
#
#             return new Function(value.substring(startArgs, endArgs),
#                                 value.substring(startBody, endBody));
#         }
#         if (check2) {
#             return eval(value);
#         }
#
#
#     }
#
#     return value;
# });
#
#
#
#     var opt = $.extend(true, {}, options);
#     if (window.opts==undefined) {
#         window.opts = {};
#     }
#     window.opts['2e381496_c323_4b67_ad13_a09d907976f5'] = opt;
#
#     console.log('Highcharts/Highstock options accessible as opts["2e381496_c323_4b67_ad13_a09d907976f5"]');
#
#
#             window.chart = new Highcharts.Chart(options);
#
#     console.log('Highcharts/Highstock chart accessible as charts["2e381496_c323_4b67_ad13_a09d907976f5"]');
#
#         });
#     });
#     </script>

# %% [markdown]
# ## Performance contributions

# %%
df_perf_contrib_kalman_voladj = (1 + prices_all.reindex(df_weight_kalman_voladj.index).pct_change()*df_weight_kalman_voladj).prod() - 1

df_perf_contrib_kalman_bic_voladj = (1 + prices_all.reindex(df_weight_kalman_bic_voladj.index).pct_change()*df_weight_kalman_bic_voladj).prod() - 1

df_perf_contrib_kalman_aic_voladj = (1 + prices_all.reindex(df_weight_kalman_aic_voladj.index).pct_change()*df_weight_kalman_aic_voladj).prod() - 1

# %%
df_perf_contrib = pd.DataFrame()
df_perf_contrib["Kalman"] = df_perf_contrib_kalman_voladj
df_perf_contrib["Kalman BIC"] = df_perf_contrib_kalman_bic_voladj
df_perf_contrib["Kalman AIC"] = df_perf_contrib_kalman_aic_voladj
df_perf_contrib = df_perf_contrib.join(df_info).reset_index()

# %%
df_perf_contrib_asset_class = df_perf_contrib.drop(["Style"],axis=1).groupby(["Asset Class","index"]).sum()
df_perf_contrib_style = df_perf_contrib.drop(["Asset Class"],axis=1).groupby(["Style","index"]).sum()

# %%
g = hc_spiderweb(df_perf_contrib_asset_class, title="Vol contribution by Asset Class")
g.plot()
# Out:
# <div id="8eb65574_258a_46d6_8ab6_ede14b11d16a"><div id="8eb65574_258a_46d6_8ab6_ede14b11d16acontainer_chart"></div></div><script>
#     // the Jupyter notebook loads jquery.min.js  and require.js and at the top of the page
#     // then to make jquery available inside a require module
#     // the trick is http://www.manuel-strehl.de/dev/load_jquery_before_requirejs.en.html
#     define('jquery', [], function() {
#         return jQuery;
#     });
#
#     require(["jquery", "https://code.highcharts.com/stock/highstock.js", "https://d3js.org/d3.v3.min.js"], function() {
#         require(["https://cdn.datatables.net/1.10.10/js/jquery.dataTables.min.js", "https://code.highcharts.com/stock/highcharts-more.js", "https://code.highcharts.com/modules/drilldown.js", "https://code.highcharts.com/modules/exporting.js", "https://code.highcharts.com/modules/heatmap.js", "https://code.highcharts.com/modules/treemap.js", "https://highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":{"enabled":true},"chart":{"animation":false,"polar":true,"width":800,"height":500,"renderTo":"8eb65574_258a_46d6_8ab6_ede14b11d16acontainer_chart"},"series":[{"name":"Kalman","data":[{"name":"Bonds","y":11.673348754,"drilldown":"Bonds - Kalman","pointPlacement":"on"},{"name":"Commodity","y":17.9185610355,"drilldown":"Commodity - Kalman","pointPlacement":"on"},{"name":"Credit","y":1.1105867472,"drilldown":"Credit - Kalman","pointPlacement":"on"},{"name":"Cross-Asset","y":44.1486329025,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":22.1498460548,"drilldown":"Equity - Kalman","pointPlacement":"on"},{"name":"FX","y":-0.2181263412,"drilldown":"FX - Kalman","pointPlacement":"on"},{"name":"MM","y":0.0653522006,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman BIC","data":[{"name":"Bonds","y":6.5122307144,"drilldown":"Bonds - Kalman BIC","pointPlacement":"on"},{"name":"Commodity","y":16.3412464845,"drilldown":"Commodity - Kalman BIC","pointPlacement":"on"},{"name":"Credit","y":-0.5533780823,"drilldown":"Credit - Kalman BIC","pointPlacement":"on"},{"name":"Cross-Asset","y":84.079235406,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":-5.5650904193,"drilldown":"Equity - Kalman BIC","pointPlacement":"on"},{"name":"FX","y":9.2574856342,"drilldown":"FX - Kalman BIC","pointPlacement":"on"},{"name":"MM","y":0.0014755147,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman AIC","data":[{"name":"Bonds","y":5.7371603954,"drilldown":"Bonds - Kalman AIC","pointPlacement":"on"},{"name":"Commodity","y":21.3541028485,"drilldown":"Commodity - Kalman AIC","pointPlacement":"on"},{"name":"Credit","y":-0.4077718076,"drilldown":"Credit - Kalman AIC","pointPlacement":"on"},{"name":"Cross-Asset","y":60.2530085602,"drilldown":null,"pointPlacement":"on"},{"name":"Equity","y":3.3683931829,"drilldown":"Equity - Kalman AIC","pointPlacement":"on"},{"name":"FX","y":6.8650445913,"drilldown":"FX - Kalman AIC","pointPlacement":"on"},{"name":"MM","y":0.0045451586,"drilldown":null,"pointPlacement":"on"}],"colorByPoint":false}],"plotOptions":{"series":{"animation":true},"line":{"animation":false},"column":{"animation":false},"bar":{"animation":false},"pie":{"animation":false},"scatter":{"animation":false},"bubble":{"animation":false},"treemap":{"animation":false}},"pane":{"size":"90%"},"title":{"text":""},"xAxis":{"type":"category","tickmarkPlacement":"on","lineWidth":0},"yAxis":{"gridLineInterpolation":"polygon","lineWidth":0,"plotLines":[{"color":"gray","value":0,"width":1.5}]},"tooltip":{"pointFormat":"<span style=\"color:{series.color}\">{series.name}: <b>{point.y:,.3f}%<\/b><br\/>","shared":true},"legend":{"enabled":true,"align":"right","verticalAlign":"top","y":70,"layout":"vertical"},"drilldown":{"series":[{"name":"Bonds - Kalman","data":[["BNPIAIRB",-1.1708192597],["BNPIFA10",0.2666326892],["BNPIFAU3",-0.0935674963],["BNPIFE10",-0.4715177088],["BNPIFE30",5.5126981956],["BNPIFEU2",0.0328703822],["BNPIFEU5",-0.0563486177],["BNPIFF10",1.3522136504],["BNPIFG10",2.7728839258],["BNPIFI10",2.1581912169],["BNPIFJ10",-2.0107960361],["BNPIFU10",0.2111009924],["BNPIFU30",1.1273222215],["BNPIFUS2",0.2899837247],["BNPIFUS5",1.7525008739]],"id":"Bonds - Kalman","pointPlacement":"on"},{"name":"Commodity - Kalman","data":[["BNPICVXA",0.2545685486],["BNPIDRXA",-0.2602588526],["BNPIF3AX",3.3196187435],["BNPIF3XM",-0.8331700254],["BNPIVCXA",0.6643688251],["SPGSBRP",-1.9364362866],["SPGSCLP",0.1988238282],["SPGSGCP",2.4264483271],["SPGSGOP",0.3414845372],["SPGSHOP",1.8148531113],["SPGSHUP",1.2809812585],["SPGSIAP",-5.0301992673],["SPGSICP",2.3161705083],["SPGSIKP",1.9150129329],["SPGSILP",1.4747860599],["SPGSIZP",1.4696559605],["SPGSNGP",3.0050301202],["SPGSSIP",5.4968227061]],"id":"Commodity - Kalman","pointPlacement":"on"},{"name":"Credit - Kalman","data":[["BNPXCEB5",-0.4601118206],["BNPXCEX5",1.1266418422],["BNPXCHY5",0.8135912218],["BNPXCI ...

# %%
g = hc_spiderweb(df_perf_contrib_style, title="Vol contribution by Style")
g.plot()
# Out:
# <div id="11c72fa3_c269_4c35_a17b_929ed5a28199"><div id="11c72fa3_c269_4c35_a17b_929ed5a28199container_chart"></div></div><script>
#     // the Jupyter notebook loads jquery.min.js  and require.js and at the top of the page
#     // then to make jquery available inside a require module
#     // the trick is http://www.manuel-strehl.de/dev/load_jquery_before_requirejs.en.html
#     define('jquery', [], function() {
#         return jQuery;
#     });
#
#     require(["jquery", "https://code.highcharts.com/stock/highstock.js", "https://d3js.org/d3.v3.min.js"], function() {
#         require(["https://cdn.datatables.net/1.10.10/js/jquery.dataTables.min.js", "https://code.highcharts.com/stock/highcharts-more.js", "https://code.highcharts.com/modules/drilldown.js", "https://code.highcharts.com/modules/exporting.js", "https://code.highcharts.com/modules/heatmap.js", "https://code.highcharts.com/modules/treemap.js", "https://highcharts.github.io/export-csv/export-csv.js"], function() {
#
#     var options = {"credits":{"enabled":false},"exporting":{"enabled":true},"chart":{"animation":false,"polar":true,"width":800,"height":500,"renderTo":"11c72fa3_c269_4c35_a17b_929ed5a28199container_chart"},"series":[{"name":"Kalman","data":[{"name":"Carry","y":10.3315046571,"drilldown":"Carry - Kalman","pointPlacement":"on"},{"name":"Classic","y":40.468821339,"drilldown":"Classic - Kalman","pointPlacement":"on"},{"name":"Low Volatility","y":-0.7865121517,"drilldown":"Low Volatility - Kalman","pointPlacement":"on"},{"name":"Momentum","y":48.6399619904,"drilldown":"Momentum - Kalman","pointPlacement":"on"},{"name":"Quality","y":-1.2494723392,"drilldown":"Quality - Kalman","pointPlacement":"on"},{"name":"Reversal","y":-0.2722164882,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":-0.5347662606,"drilldown":"Value - Kalman","pointPlacement":"on"},{"name":"Volatility","y":0.2508806064,"drilldown":"Volatility - Kalman","pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman BIC","data":[{"name":"Carry","y":4.1916673059,"drilldown":"Carry - Kalman BIC","pointPlacement":"on"},{"name":"Classic","y":19.0661946062,"drilldown":"Classic - Kalman BIC","pointPlacement":"on"},{"name":"Low Volatility","y":-0.0051246529,"drilldown":"Low Volatility - Kalman BIC","pointPlacement":"on"},{"name":"Momentum","y":86.9614331429,"drilldown":"Momentum - Kalman BIC","pointPlacement":"on"},{"name":"Quality","y":0.0031203268,"drilldown":"Quality - Kalman BIC","pointPlacement":"on"},{"name":"Reversal","y":0.0112626182,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":-0.0894553962,"drilldown":"Value - Kalman BIC","pointPlacement":"on"},{"name":"Volatility","y":-0.0658926985,"drilldown":"Volatility - Kalman BIC","pointPlacement":"on"}],"colorByPoint":false},{"name":"Kalman AIC","data":[{"name":"Carry","y":4.9520009873,"drilldown":"Carry - Kalman AIC","pointPlacement":"on"},{"name":"Classic","y":26.2110014875,"drilldown":"Classic - Kalman AIC","pointPlacement":"on"},{"name":"Low Volatility","y":0.0461797663,"drilldown":"Low Volatility - Kalman AIC","pointPlacement":"on"},{"name":"Momentum","y":65.9141429847,"drilldown":"Momentum - Kalman AIC","pointPlacement":"on"},{"name":"Quality","y":-0.000976448,"drilldown":"Quality - Kalman AIC","pointPlacement":"on"},{"name":"Reversal","y":1.2794443925,"drilldown":null,"pointPlacement":"on"},{"name":"Value","y":-0.9479431524,"drilldown":"Value - Kalman AIC","pointPlacement":"on"},{"name":"Volatility","y":-0.2793670885,"drilldown":"Volatility - Kalman AIC","pointPlacement":"on"}],"colorByPoint":false}],"plotOptions":{"series":{"animation":true},"line":{"animation":false},"column":{"animation":false},"bar":{"animation":false},"pie":{"animation":false},"scatter":{"animation":false},"bubble":{"animation":false},"treemap":{"animation":false}},"pane":{"size":"90%"},"title":{"text":""},"xAxis":{"type":"category","tickmarkPlacement":"on","lineWidth":0},"yAxis":{"gridLineInterpolation":"polygon","lineWidth":0,"plotLines":[{"color":"gray","value":0,"width":1.5}]},"tooltip":{"pointFormat":"<span style=\"color:{series.color}\">{series.name}: <b>{point.y:,.3f}%<\/b><br\/>","shared":true},"legend":{"enabled":true,"align":"right","verticalAlign":"top","y":70,"layout":"vertical"},"drilldown":{"series":[{"name":"Carry - Kalman","data":[["BNPICCE3",1.9148053226],["BNPIDRXA",-0.2602588526],["BNPIEC03",2.9508042003],["BNPIF3AX",3.3196187435],["BPCURVW4",0.0653522006],["BPFXGGUR",2.3411830428]],"id":"Carry - Kalman","pointPlacement":"on"},{"name":"Classic - Kalman","data":[["BNPIFA10",0.2666326892],["BNPIFAU",-2.1628599481],["BNPIFAU3",-0.0935674963],["BNPIFBR",0.3140902932],["BNPIFCH",1.6018565796],["BNPIFCN",2.6987535876],["BNPIFE10",-0.4715177088],["BNPIFE30",5.5126981956],["BNPIFEM",2.3264909513],["BNPIFEU",5.3083787937],["BNPIFEU2",0.0328703822],["BNPIFEU5",-0.0563486177],["BNPIFF10",1.3522136504],["BNPIFFR",-0.6384360698],["BNPIFG10",2.7728839258],["BNPIFGB",-1.2619826684],["BNPIFGE",3.3564709682],["BNPIFHK", ...

# %% [markdown]
# ## Average exposures

# %%
(df_weight_aic).mean(axis=0).plot(kind='barh', figsize=(15,20))

# %%
(df_weight_bic).mean(axis=0).plot(kind='barh', figsize=(15,20))

# %%
df_weight_kalman.loc[df_res.index[0]:].mean(axis=0).plot(kind='barh', figsize=(15,20))

# %%
df_weight_kalman_bic.loc[df_res.index[0]:].mean(axis=0).plot(kind='barh', figsize=(15,20))

# %%
df_weight_kalman_aic.loc[df_res.index[0]:].mean(axis=0).plot(kind='barh', figsize=(15,20))

# %%
limit = 60
df_autocorr = pd.DataFrame(data=[df_res.drop(["Lasso AIC","Lasso BIC"],axis=1)\
                                 .pct_change().apply(lambda col : col.autocorr(lag=i)) for i in range(1,limit)])
df_autocorr[r"$2/\sqrt{n}$"] = [2/np.sqrt(len(df_res)-i) for i in range(1,limit)]
df_autocorr[r"$-2/\sqrt{n}$"] = [-2/np.sqrt(len(df_res)-i) for i in range(1,limit)]

# %%
df_autocorr.plot(figsize=(14,7))

# %%
df_res[fund_name].pct_change().autocorr(lag=1)
# Out:
# 0.070657055482061568

# %%
df_res['Kalman'].pct_change().autocorr(lag=1)
# Out:
# 0.087969519555188988

# %%
df_res['Kalman BIC'].pct_change().autocorr(lag=1)
# Out:
# 0.069559575807110585

# %%
df_res['Kalman AIC'].pct_change().autocorr(lag=1)
# Out:
# 0.070429955198902619

# %%
df_res['Lasso AIC'].pct_change().autocorr(lag=1)
# Out:
# 0.073653741733911926
